# %%
# Install necessary packages
# !sudo apt update
# !sudo apt install wget git curl -y
# Out:
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic InRelease [242 kB]
# Get:3 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [8,815 B]
# Get:4 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [930 kB]
# Get:5 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [59.3 kB]
# Get:6 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [852 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]m
# Get:8 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/universe amd64 Packages [11.3 MB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 Packages [186 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/restricted amd64 Packages [13.5 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 Packages [1,344 kB]
# ...

# %%
# Install Java 8
# !sudo wget https://www.dropbox.com/s/u01js72eg57tjep/install-java8.bash
# !sudo chmod 755 install-java8.bash
# !sudo ./install-java8.bash

# %%
# Get code
# !sudo git clone https://github.com/farzadrastegar/blog-microservices.git && cd blog-microservices && sudo git checkout B2F
# Out:
# Cloning into 'blog-microservices'...
# remote: Enumerating objects: 52, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 6270 (delta 5), reused 38 (delta 2), pack-reused 6218
# Receiving objects: 100% (6270/6270), 1.18 MiB | 18.64 MiB/s, done.
# Resolving deltas: 100% (2262/2262), done.
# Branch 'B2F' set up to track remote branch 'B2F' from 'origin'.
# Switched to a new branch 'B2F'

# %%
# Build code
# !cd && cd blog-microservices && sudo ./build-all.sh
# Out:
# ...
# ......................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# ...

# %%
# Run the service discovery server, i.e. Eureka
# !cd && echo "#!/bin/bash" > run-eureka.bash
# !cd && echo "cd; cd blog-microservices/microservices/support/discovery-server; sudo touch out; sudo chmod 666 out; nohup sudo ./gradlew bootRun >out 2>&1 &" >> run-eureka.bash
# !cd && sudo chmod 755 run-eureka.bash && sudo ./run-eureka.bash

# %%
# Run the edge server
# !cd && echo "#!/bin/bash" > run-edge.bash
# !cd && echo "cd; cd blog-microservices/microservices/support/edge-server; sudo nohup sudo ./gradlew bootRun >/dev/null 2>&1 &" >> run-edge.bash
# !cd && sudo chmod 755 run-edge.bash && sudo ./run-edge.bash

# %%
# Get Eureka URL

## Install ngrok
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip

## Run ngrok to tunnel the Eureka dashboard port 8761 to the outside world. 
## This command runs in the background.
get_ipython().system_raw('./ngrok http 8761 &')

## Get the public URL where you can access the dashboard. Copy this URL (make sure you are already logged in at ngrok.io).
! curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# --2020-05-23 23:51:37--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 52.204.235.107, 3.229.211.71, 34.196.154.11, ...
# Connecting to bin.equinox.io (bin.equinox.io)|52.204.235.107|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13773305 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]  13.13M  72.2MB/s    in 0.2s
#
# 2020-05-23 23:51:38 (72.2 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [13773305/13773305]
#
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok
# http://5fdd9f2f.ngrok.io
